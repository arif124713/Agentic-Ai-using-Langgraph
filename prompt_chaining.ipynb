# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
# Out:
# c:\Users\UNIQUE\PycharmProjects\Langgraph\.venv\Lib\site-packages\langgraph\cache\base\__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

# %%
model= ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite",api_key=api_key)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState)->BlogState:
    title= state['title']
    prompt= f'write a outline for a blog on this topic {title}'
    outline= model.invoke(prompt).content
    state['outline']= outline

    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title= state['title']
    outline= state['outline']
    prompt= f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'
    content= model.invoke(prompt).content
    state['content']= content

    return state

# %%
graph= StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog', END)
workflow= graph.compile()

# %%
initial_state={'title':'How to promote micro apps or indie SaaS'}
final_state=workflow.invoke(initial_state)

# %%
final_state
# Out:
# {'title': 'How to promote micro apps or indie SaaS',
#  'outline': '## Blog Outline: **Unlocking Growth: How to Promote Your Micro App or Indie SaaS**\n\n**Target Audience:** Indie SaaS founders, micro-app developers, solo entrepreneurs, bootstrapped businesses.\n\n**Overall Goal:** To provide actionable strategies and a clear roadmap for effectively promoting micro-apps and indie SaaS products in a crowded market.\n\n---\n\n### **I. Introduction: The Rise of Micro Apps & Indie SaaS (The Opportunity & The Challenge)**\n\n*   **A. Hook:** Start with a compelling statistic or anecdote about the growth of micro-SaaS/app market, or the success of a well-known indie product.\n    *   *Example:* "In a world saturated with enterprise giants, a new breed of agile, focused solutions is taking the market by storm..."\n*   **B. Define Micro Apps & Indie SaaS:** Briefly explain what they are and why they\'re gaining traction (niche focus, affordability, agility, direct customer connection).\n*   **C. The Core Challenge:** Acknowledge the primary hurdle – visibility and reaching the right audience in a noisy landscape.\n*   **D. Thesis Statement/Blog\'s Promise:** "This guide will equip you with proven strategies to cut through the noise, attract your ideal users, and build a sustainable business for your micro app or indie SaaS."\n\n---\n\n### **II. Laying the Foundation: Understanding Your Product & Audience**\n\n*   **A. Know Your "Why":**\n    *   What specific problem does your micro app/SaaS solve? (Be razor-sharp!)\n    *   What makes your solution unique or better than existing alternatives?\n*   **B. Define Your Ideal Customer Profile (ICP):**\n    *   Who are they? (Demographics, psychographics, job titles, company size)\n    *   Where do they hang out online? (Forums, social media groups, specific websites)\n    *   What are their pain points and aspirations related to your solution?\n*   **C. Craft Your Core Messaging:**\n    *   Develop a clear, concise, and compelling value proposition.\n    *   Focus on benefits, not just features.\n    *   Create a strong elevator pitch.\n\n---\n\n### **III. Building Your Online Presence: Where Your Audience Lives**\n\n*   **A. Your Website/Landing Page: The Digital Storefront**\n    *   **Essential Elements:** Clear headline, benefit-driven copy, strong call-to-action (CTA), social proof (testimonials, logos), demo/video.\n    *   **SEO Basics:** Keyword research for your niche, on-page optimization.\n    *   **User Experience (UX):** Mobile-friendliness, fast loading times, intuitive navigation.\n*   **B. Content Marketing: Becoming a Thought Leader**\n    *   **Blog Posts:** Address pain points, offer solutions, share case studies, tutorials.\n    *   **Guides & Ebooks:** Deeper dives into your niche.\n    *   **Templates & Checklists:** Practical, downloadable resources.\n    *   **Webinars & Live Demos:** Interactive engagement.\n*   **C. Social Media Strategy: Engaging & Amplifying**\n    *   **Platform Selection:** Where does your ICP spend time? (LinkedIn, Twitter, Reddit, Niche Forums, TikTok, etc.)\n    *   **Content Pillars:** What kind of content will resonate? (Tips, behind-the-scenes, user-generated content, industry news).\n    *   **Engagement is Key:** Respond to comments, participate in conversations.\n    *   **Leveraging Niche Communities:** Actively participate in relevant subreddits, Slack communities, Discord servers.\n\n---\n\n### **IV. Driving Traffic & Acquiring Users: Proven Promotion Tactics**\n\n*   **A. Organic Growth Strategies:**\n    *   **Search Engine Optimization (SEO):**\n        *   Long-tail keywords specific to your micro-niche.\n        *   Building backlinks through guest posting and collaborations.\n    *   **Community Building:**\n        *   Creating your own community (Slack, Discord, Facebook Group).\n        *   Active participation in existing communities.\n    *   **Word-of-Mouth & Referrals:**\n        *   Incentivize sharing (referral programs).\n        *   Provide exceptional customer servic ...
#  'content': '## Unlocking Growth: How to Promote Your Micro App or Indie SaaS\n\nIn a world saturated with enterprise giants and complex software suites, a new breed of agile, focused solutions is taking the market by storm. We\'re talking about micro apps and indie SaaS products – lean, mean problem-solving machines built by passionate individuals and small teams. These innovative offerings are gaining traction for their affordability, agility, and the direct, personal connection they offer to their users.\n\nBut with this rise comes a significant challenge: **visibility**. How do you ensure your brilliant micro app or indie SaaS gets discovered amidst the digital cacophony? How do you reach the right audience when your budget is lean and your team is small?\n\nFear not, intrepid founders! This guide is your roadmap. We\'ll equip you with proven strategies to cut through the noise, attract your ideal users, and build a sustainable, thriving business for your micro app or indie SaaS.\n\n---\n\n### **I. Laying the Foundation: Understanding Your Product & Audience**\n\nBefore you even think about shouting from the digital rooftops, you need to deeply understand what you\'re selling and who you\'re selling it to. This isn\'t just good marketing practice; it\'s the bedrock of effective promotion.\n\n**A. Know Your "Why": The Laser Focus**\n\n*   **What specific problem does your micro app/SaaS solve?** This needs to be razor-sharp. Don\'t be vague. Instead of "helps businesses manage tasks," be specific: "helps freelance graphic designers track project deadlines and client communication in one place."\n*   **What makes your solution unique or better than existing alternatives?** Is it simpler? More affordable? Does it offer a specific feature no one else does? Is your customer support legendary? Pinpoint your competitive edge.\n\n**B. Define Your Ideal Customer Profile (ICP): The Perfect Fit**\n\n*   **Who are they?** Go beyond basic demographics. Think psychographics: their values, their motivations, their fears. What are their job titles? What size companies do they work for (if applicable)?\n*   **Where do they hang out online?** This is crucial for targeted promotion. Are they in specific subreddits? LinkedIn groups? Niche forums? Certain industry Slack communities? Which social media platforms do they frequent?\n*   **What are their pain points and aspirations related to your solution?** Empathize deeply. What keeps them up at night? What are they dreaming of achieving? Your product should be the bridge from their pain to their aspiration.\n\n**C. Craft Your Core Messaging: The Compelling Narrative**\n\n*   **Develop a clear, concise, and compelling value proposition.** This is your elevator pitch, distilled. It should immediately tell a potential user what you do, who you do it for, and why they should care.\n*   **Focus on benefits, not just features.** Instead of saying "our app has a robust reporting dashboard," say "gain instant clarity on your project\'s profitability with our intuitive reporting dashboard, so you can make smarter business decisions."\n*   **Create a strong elevator pitch.** Practice it. Make it memorable. It should be something you can confidently share in any networking situation.\n\n---\n\n### **II. Building Your Online Presence: Where Your Audience Lives**\n\nOnce you know *what* you\'re selling and *who* you\'re selling to, it\'s time to establish your digital footprint where your audience can find you.\n\n**A. Your Website/Landing Page: The Digital Storefront**\n\nYour website is your digital storefront. It needs to be more than just a brochure; it needs to convert visitors into users.\n\n*   **Essential Elements:**\n    *   **Clear Headline:** Immediately grab attention and state your value proposition.\n    *   **Benefit-Driven Copy:** Speak directly to your ICP\'s pain points and aspirations.\n    *   **Strong Call-to-Action (CTA):** Tell users exactly what you want them to do (e.g., "Start Fre ...

# %%
final_state['outline']
# Out:
# '## Blog Outline: **Unlocking Growth: How to Promote Your Micro App or Indie SaaS**\n\n**Target Audience:** Indie SaaS founders, micro-app developers, solo entrepreneurs, bootstrapped businesses.\n\n**Overall Goal:** To provide actionable strategies and a clear roadmap for effectively promoting micro-apps and indie SaaS products in a crowded market.\n\n---\n\n### **I. Introduction: The Rise of Micro Apps & Indie SaaS (The Opportunity & The Challenge)**\n\n*   **A. Hook:** Start with a compelling statistic or anecdote about the growth of micro-SaaS/app market, or the success of a well-known indie product.\n    *   *Example:* "In a world saturated with enterprise giants, a new breed of agile, focused solutions is taking the market by storm..."\n*   **B. Define Micro Apps & Indie SaaS:** Briefly explain what they are and why they\'re gaining traction (niche focus, affordability, agility, direct customer connection).\n*   **C. The Core Challenge:** Acknowledge the primary hurdle – visibility and reaching the right audience in a noisy landscape.\n*   **D. Thesis Statement/Blog\'s Promise:** "This guide will equip you with proven strategies to cut through the noise, attract your ideal users, and build a sustainable business for your micro app or indie SaaS."\n\n---\n\n### **II. Laying the Foundation: Understanding Your Product & Audience**\n\n*   **A. Know Your "Why":**\n    *   What specific problem does your micro app/SaaS solve? (Be razor-sharp!)\n    *   What makes your solution unique or better than existing alternatives?\n*   **B. Define Your Ideal Customer Profile (ICP):**\n    *   Who are they? (Demographics, psychographics, job titles, company size)\n    *   Where do they hang out online? (Forums, social media groups, specific websites)\n    *   What are their pain points and aspirations related to your solution?\n*   **C. Craft Your Core Messaging:**\n    *   Develop a clear, concise, and compelling value proposition.\n    *   Focus on benefits, not just features.\n    *   Create a strong elevator pitch.\n\n---\n\n### **III. Building Your Online Presence: Where Your Audience Lives**\n\n*   **A. Your Website/Landing Page: The Digital Storefront**\n    *   **Essential Elements:** Clear headline, benefit-driven copy, strong call-to-action (CTA), social proof (testimonials, logos), demo/video.\n    *   **SEO Basics:** Keyword research for your niche, on-page optimization.\n    *   **User Experience (UX):** Mobile-friendliness, fast loading times, intuitive navigation.\n*   **B. Content Marketing: Becoming a Thought Leader**\n    *   **Blog Posts:** Address pain points, offer solutions, share case studies, tutorials.\n    *   **Guides & Ebooks:** Deeper dives into your niche.\n    *   **Templates & Checklists:** Practical, downloadable resources.\n    *   **Webinars & Live Demos:** Interactive engagement.\n*   **C. Social Media Strategy: Engaging & Amplifying**\n    *   **Platform Selection:** Where does your ICP spend time? (LinkedIn, Twitter, Reddit, Niche Forums, TikTok, etc.)\n    *   **Content Pillars:** What kind of content will resonate? (Tips, behind-the-scenes, user-generated content, industry news).\n    *   **Engagement is Key:** Respond to comments, participate in conversations.\n    *   **Leveraging Niche Communities:** Actively participate in relevant subreddits, Slack communities, Discord servers.\n\n---\n\n### **IV. Driving Traffic & Acquiring Users: Proven Promotion Tactics**\n\n*   **A. Organic Growth Strategies:**\n    *   **Search Engine Optimization (SEO):**\n        *   Long-tail keywords specific to your micro-niche.\n        *   Building backlinks through guest posting and collaborations.\n    *   **Community Building:**\n        *   Creating your own community (Slack, Discord, Facebook Group).\n        *   Active participation in existing communities.\n    *   **Word-of-Mouth & Referrals:**\n        *   Incentivize sharing (referral programs).\n        *   Provide exceptional customer service to encoura ...
